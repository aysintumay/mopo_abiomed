# %%
import matplotlib.pyplot as plt
print("Open figure IDs:", plt.get_fignums())
plt.close('all')   # closes every open figure
print("After close:", plt.get_fignums())

# --- Weights & Biases: check if a run is active & finish it ---
import wandb
print("Active W&B run:", wandb.run)   # None if no run
if wandb.run is not None:
    wandb.finish()
# Out:
# Open figure IDs: []
# After close: []
# Active W&B run: None
